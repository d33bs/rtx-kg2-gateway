# %% [markdown]
# # Generate RTX-KG2 Metanames Parquet for Kuzu

# %%
import gzip
import json
import pathlib
import shutil
from typing import Any, Dict, Generator, List, Literal

import awkward as ak
import duckdb
import ijson
import kuzu
import pyarrow as pa
import requests
from genson import SchemaBuilder
from pyarrow import parquet
from rtx_kg2_functions import (
    count_items_under_top_level_name,
    drop_table_if_exists,
    find_top_level_names,
    generate_cypher_table_create_stmt_from_parquet_file,
    parse_items_by_topmost_item_name,
    parse_metadata_by_object_name,
)

# %%
# set data to be used throughout notebook
chunk_size = 500000
data_dir = "data"
parquet_dir = f"{data_dir}/"
source_data_url = "https://github.com/ncats/translator-lfs-artifacts/raw/main/files/kg2c_lite_2.8.4.json.gz"
target_extracted_sample_data = (
    f"{data_dir}/{pathlib.Path(source_data_url).name.replace('.json.gz', '.json')}"
)
parquet_dir = target_extracted_sample_data.replace(".json", ".full.dataset.parquet")
parquet_metanames_dir = target_extracted_sample_data.replace(
    ".json", ".full.with-metanames.dataset.parquet"
)
kuzu_dir = target_extracted_sample_data.replace(
    ".json", ".full.with-metanames.dataset.kuzu"
)
target_extracted_sample_data_schema_file = target_extracted_sample_data.replace(
    ".json", ".schema.json"
)
print(f"Kuzu dir: {kuzu_dir}")
# Out:
# Kuzu dir: data/kg2c_lite_2.8.4.full.with-metanames.dataset.kuzu

# %%
# create path for the kuzu database to reside
if pathlib.Path(kuzu_dir).is_dir():
    shutil.rmtree(kuzu_dir)
pathlib.Path(kuzu_dir).mkdir(exist_ok=True)

# %%
# create path for parquet metanames to reside
if pathlib.Path(parquet_metanames_dir).is_dir():
    shutil.rmtree(parquet_metanames_dir)
pathlib.Path(parquet_metanames_dir).mkdir(exist_ok=True)

# %%
# init a Kuzu database and connection
db = kuzu.Database(f"{kuzu_dir}")
kz_conn = kuzu.Connection(db)

# %%
def gather_table_names_from_parquet_path(
    parquet_path: str,
    column_with_table_name: str = "id",
):
    # return distinct table types as set comprehension
    return set(
        # create a parquet dataset and read a single column as an array
        parquet.ParquetDataset(parquet_path)
        .read(columns=[column_with_table_name])[column_with_table_name]
        .to_pylist()
    )

# %%
for path, table_name_column in [
    [f"{parquet_dir}/nodes", "category"],
    [f"{parquet_dir}/edges", "predicate"],
]:

    # create object base dir
    parquet_metanames_object_base = f"{parquet_metanames_dir}/{pathlib.Path(path).name}"
    pathlib.Path(parquet_metanames_object_base).mkdir(exist_ok=True)

    for table_name in gather_table_names_from_parquet_path(
        parquet_path=path, column_with_table_name=table_name_column
    ):
        # create metanames / objects using cypher safe name and dir
        cypher_safe_table_name = table_name.split(":")[1]
        parquet_metanames_metaname_base = (
            f"{parquet_metanames_object_base}/{cypher_safe_table_name}"
        )
        pathlib.Path(parquet_metanames_metaname_base).mkdir(exist_ok=True)

        print(f"Exporting metaname tables for: {table_name}")
        if pathlib.Path(path).name == "nodes":
            # determine rowcount for offsetting parquet files by metaname
            with duckdb.connect() as ddb:
                rowcount = int(
                    ddb.execute(
                        f"""
                        SELECT COUNT(*) as count
                        FROM read_parquet('{path}/*')
                        WHERE {table_name_column}='{table_name}';
                        """
                    ).fetchone()[0]
                )

            # create a chunk offsets list for chunked parquet output by metaname
            chunk_offsets = list(
                range(
                    0,
                    # gather rowcount from table and use as maximum for range
                    rowcount,
                    # step through using chunk size
                    chunk_size,
                )
            )

            # gather chunks of data by metaname and export to file using chunked offsets
            with duckdb.connect() as ddb:
                for idx, offset in enumerate(chunk_offsets):
                    ddb.execute(
                        f"""
                        COPY (
                            SELECT *
                            FROM read_parquet('{path}/*')
                            WHERE {table_name_column}='{table_name}'
                            LIMIT {chunk_size} OFFSET {offset}
                        )
                        TO '{parquet_metanames_metaname_base}/{cypher_safe_table_name}.{idx}.parquet' (FORMAT PARQUET);
                        """
                    )
        elif pathlib.Path(path).name == "edges":

            nodes_path = path.replace("edges", "nodes")
            with duckdb.connect() as ddb:
                distinct_node_type_pairs = ddb.execute(
                    f"""
                    SELECT DISTINCT 
                        split_part(subj_node.category, ':', 2) as subj_category,
                        split_part(obj_node.category, ':', 2) as obj_category
                    FROM read_parquet('{path}/*') edge
                    LEFT JOIN read_parquet('{nodes_path}/*') AS subj_node ON
                        edge.subject = subj_node.id
                    LEFT JOIN read_parquet('{nodes_path}/*') AS obj_node ON
                        edge.object = obj_node.id
                    WHERE edge.predicate='{table_name}'
                    """
                ).fetchall()

            for subj, obj in distinct_node_type_pairs:
                
                # determine rowcount for offsetting parquet files by metaname
                with duckdb.connect() as ddb:
                    rowcount = int(
                        ddb.execute(
                            f"""
                            SELECT COUNT(*) as count
                            FROM read_parquet('{path}/*')
                            WHERE {table_name_column}='{table_name}';
                            """
                        ).fetchone()[0]
                    )
    
                # create a chunk offsets list for chunked parquet output by metaname
                chunk_offsets = list(
                    range(
                        0,
                        # gather rowcount from table and use as maximum for range
                        rowcount,
                        # step through using chunk size
                        chunk_size,
                    )
                )
    
                # gather chunks of data by metaname and export to file using chunked offsets
                with duckdb.connect() as ddb:
                    for idx, offset in enumerate(chunk_offsets):
                        ddb.execute(
                            f"""
                            COPY (
                                SELECT *
                                FROM read_parquet('{path}/*')
                                WHERE {table_name_column}='{table_name}'
                                LIMIT {chunk_size} OFFSET {offset}
                            )
                            TO '{parquet_metanames_metaname_base}/{cypher_safe_table_name}.{idx}.parquet' (FORMAT PARQUET);
                            """
                        )
# Out:
# Exporting metaname tables for: biolink:Transcript
# Exporting metaname tables for: biolink:MicroRNA
# Exporting metaname tables for: biolink:Behavior
# Exporting metaname tables for: biolink:Drug
# Exporting metaname tables for: biolink:MolecularActivity
# Exporting metaname tables for: biolink:GrossAnatomicalStructure
# Exporting metaname tables for: biolink:Exon
# Exporting metaname tables for: biolink:ChemicalEntity
# Exporting metaname tables for: biolink:Phenomenon
# Exporting metaname tables for: biolink:CellLine
# Exporting metaname tables for: biolink:GenomicEntity
# Exporting metaname tables for: biolink:Device
# Exporting metaname tables for: biolink:Cell
# Exporting metaname tables for: biolink:LifeStage
# Exporting metaname tables for: biolink:Publication
# Exporting metaname tables for: biolink:EnvironmentalProcess
# Exporting metaname tables for: biolink:CellularComponent
# Exporting metaname tables for: biolink:Gene
# Exporting metaname tables for: biolink:NoncodingRNAProduct
# Exporting metaname tables for: biolink:OrganismTaxon
# Exporting metaname tables for: biolink:RetrievalSource
# Exporting metaname tables for: biolink:IndividualOrganism
# Exporting metaname tables for: biolink:PhenotypicFeature
# Exporting metaname tables for: biolink:BiologicalProcess
# Exporting metaname tables for: biolink:Procedure
# Exporting metaname tables for: biolink:GeneticInheritance
# Exporting metaname tables for: biolink:AnatomicalEntity
# Exporting metaname tables for: biolink:Disease
# Exporting metaname tables for: biolink:OrganismalEntity
# Exporting metaname tables for: biolink:OrganismAttribute
# Exporting metaname tables for: biolink:NamedThing
# Exporting metaname tables for: biolink:PopulationOfIndividualOrganisms
# Exporting metaname tables for: biolink:MaterialSample
# Exporting metaname tables for: biolink:GeographicLocation
# Exporting metaname tables for: biolink:ProteinFamily
# Exporting metaname tables for: biolink:Food
# Exporting metaname tables for: biolink:PathologicalProcess
# Exporting metaname tables for: biolink:Protein
# Exporting metaname tables for: biolink:Polypeptide
# Exporting metaname tables for: biolink:PhysicalEntity
# Exporting metaname tables for: biolink:SmallMolecule
# Exporting metaname tables for: biolink:Cohort
# Exporting metaname tables for: biolink:GeneFamily
# Exporting metaname tables for: biolink:Treatment
# Exporting metaname tables for: biolink:Event
# Exporting metaname tables for: biolink:BehavioralFeature
# Exporting metaname tables for: biolink:BiologicalEntity
# Exporting metaname tables for: biolink:EnvironmentalFeature
# Exporting metaname tables for: biolink:ProteinDomain
# Exporting metaname tables for: biolink:Agent
# Exporting metaname tables for: biolink:MolecularMixture
# Exporting metaname tables for: biolink:ClinicalAttribute
# Exporting metaname tables for: biolink:Activity
# Exporting metaname tables for: biolink:PhysiologicalProcess
# Exporting metaname tables for: biolink:NucleicAcidEntity
# Exporting metaname tables for: biolink:ComplexMolecularMixture
# Exporting metaname tables for: biolink:ChemicalMixture
# Exporting metaname tables for: biolink:RNAProduct
# Exporting metaname tables for: biolink:DiseaseOrPhenotypicFeature
# Exporting metaname tables for: biolink:Pathway
# Exporting metaname tables for: biolink:ClinicalIntervention
# Exporting metaname tables for: biolink:MolecularEntity
# Exporting metaname tables for: biolink:InformationContentEntity
# Exporting metaname tables for: biolink:has_completed
# Exporting metaname tables for: biolink:manifestation_of
# Exporting metaname tables for: biolink:physically_interacts_with
# Exporting metaname tables for: biolink:capable_of
# Exporting metaname tables for: biolink:has_output
# Exporting metaname tables for: biolink:produces
# Exporting metaname tables for: biolink:has_not_completed
# Exporting metaname tables for: biolink:derives_from
# Exporting metaname tables for: biolink:has_decreased_amount
# Exporting metaname tables for: biolink:close_match
# Exporting metaname tables for: biolink:has_increased_amount
# Exporting metaname tables for: biolink:precedes
# Exporting metaname tables for: biolink:related_to
# Exporting metaname tables for: biolink:overlaps
# Exporting metaname tables for: biolink:has_plasma_membrane_part
# Exporting metaname tables for: biolink:occurs_in
# Exporting metaname tables for: biolink:treats
# Exporting metaname tables for: biolink:predisposes
# Exporting metaname tables for: biolink:transcribed_from
# Exporting metaname tables for: biolink:coexists_with
# Exporting metaname tables for: biolink:actively_involved_in
# Exporting metaname tables for: biolink:located_in
# Exporting metaname tables for: biolink:has_participant
# Exporting metaname tables for: biolink:has_metabolite
# Exporting metaname tables for: biolink:has_molecular_consequence
# Exporting metaname tables for: biolink:colocalizes_with
# Exporting metaname tables for: biolink:chemically_similar_to
# Exporting metaname tables for: biolink:biomarker_for
# Exporting metaname tables for: biolink:enables
# Exporting metaname tables for: biolink:homologous_to
# Exporting metaname tables for: biolink:has_phenotype
# Exporting metaname tables for: biolink:prevents
# Exporting metaname tables for: biolink:exacerbates
# Exporting metaname tables for: biolink:expressed_in
# Exporting metaname tables for: biolink:associated_with
# Exporting metaname tables for: biolink:gene_associated_with_condition
# Exporting metaname tables for: biolink:same_as
# Exporting metaname tables for: biolink:model_of
# Exporting metaname tables for: biolink:diagnoses
# Exporting metaname tables for: biolink:develops_from
# Exporting metaname tables for: biolink:subclass_of
# Exporting metaname tables for: biolink:disease_has_location
# Exporting metaname tables for: biolink:disrupts
# Exporting metaname tables for: biolink:gene_product_of
# Exporting metaname tables for: biolink:causes
# Exporting metaname tables for: biolink:affects
# Exporting metaname tables for: biolink:regulates
# Exporting metaname tables for: biolink:has_part
# Exporting metaname tables for: biolink:disease_has_basis_in
# Exporting metaname tables for: biolink:composed_primarily_of
# Exporting metaname tables for: biolink:temporally_related_to
# Exporting metaname tables for: biolink:contributes_to
# Exporting metaname tables for: biolink:is_sequence_variant_of
# Exporting metaname tables for: biolink:translates_to
# Exporting metaname tables for: biolink:indirectly_physically_interacts_with
# Exporting metaname tables for: biolink:catalyzes
# Exporting metaname tables for: biolink:has_input
# Exporting metaname tables for: biolink:directly_physically_interacts_with
# Exporting metaname tables for: biolink:lacks_part
# Exporting metaname tables for: biolink:mentions
# Exporting metaname tables for: biolink:contraindicated_for
# Exporting metaname tables for: biolink:in_taxon
# Exporting metaname tables for: biolink:has_member
# Exporting metaname tables for: biolink:superclass_of
# Exporting metaname tables for: biolink:correlated_with

# %%
with duckdb.connect() as ddb:
    result = ddb.execute("""
                SELECT DISTINCT 
                split_part(subj_node.category, ':', 2) as subj_category,
                        split_part(obj_node.category, ':', 2) as obj_category
            FROM read_parquet('data/kg2c_lite_2.8.4.full.dataset.parquet/edges/*') edge
            LEFT JOIN read_parquet('data/kg2c_lite_2.8.4.full.dataset.parquet/nodes/*') AS subj_node ON
                edge.subject = subj_node.id
            LEFT JOIN read_parquet('data/kg2c_lite_2.8.4.full.dataset.parquet/nodes/*') AS obj_node ON
                edge.object = obj_node.id
            WHERE edge.predicate='biolink:causes'
    """).fetchall()
result
# Out:
# [('Activity', 'Disease'),
#  ('InformationContentEntity', 'Disease'),
#  ('PhenotypicFeature', 'PhysiologicalProcess'),
#  ('Gene', 'Disease'),
#  ('GenomicEntity', 'PhysiologicalProcess'),
#  ('ChemicalEntity', 'MolecularActivity'),
#  ('SmallMolecule', 'InformationContentEntity'),
#  ('SmallMolecule', 'Procedure'),
#  ('ChemicalEntity', 'Phenomenon'),
#  ('OrganismTaxon', 'InformationContentEntity'),
#  ('Gene', 'Activity'),
#  ('MolecularMixture', 'PhysiologicalProcess'),
#  ('ClinicalAttribute', 'PhenotypicFeature'),
#  ('ComplexMolecularMixture', 'Disease'),
#  ('Phenomenon', 'PhenotypicFeature'),
#  ('SmallMolecule', 'BiologicalEntity'),
#  ('Procedure', 'PhysiologicalProcess'),
#  ('NucleicAcidEntity', 'PhysiologicalProcess'),
#  ('NucleicAcidEntity', 'GeneticInheritance'),
#  ('OrganismTaxon', 'BiologicalEntity'),
#  ('Cell', 'PhenotypicFeature'),
#  ('SmallMolecule', 'Cohort'),
#  ('CellularComponent', 'PhenotypicFeature'),
#  ('Device', 'NamedThing'),
#  ('Protein', 'OrganismAttribute'),
#  ('Disease', 'OrganismAttribute'),
#  ('Gene', 'Behavior'),
#  ('Publication', 'PhenotypicFeature'),
#  ('Polypeptide', 'InformationContentEntity'),
#  ('IndividualOrganism', 'MolecularActivity'),
#  ('PhysiologicalProcess', 'DiseaseOrPhenotypicFeature'),
#  ('DiseaseOrPhenotypicFeature', 'Disease'),
#  ('IndividualOrganism', 'Phenomenon'),
#  ('Drug', 'DiseaseOrPhenotypicFeature'),
#  ('Polypeptide', 'BiologicalEntity'),
#  ('Device', 'ClinicalAttribute'),
#  ('Drug', 'PathologicalProcess'),
#  ('InformationContentEntity', 'Activity'),
#  ('PhysiologicalProcess', 'AnatomicalEntity'),
#  ('Activity', 'Activity'),
#  ('Food', 'PhysiologicalProcess'),
#  ('BiologicalEntity', 'OrganismAttribute'),
#  ('MolecularMixture', 'GeneticInheritance'),
#  ('GeneticInheritance', 'ClinicalAttribute'),
#  ('Activity', 'Behavior'),
#  ('OrganismTaxon', 'Procedure'),
#  ('NamedThing', 'InformationContentEntity'),
#  ('Drug', 'BiologicalProcess'),
#  ('PhysiologicalProcess', 'BiologicalProcess'),
#  ('NamedThing', 'Procedure'),
#  ('BiologicalProcess', 'Activity'),
#  ('Treatment', 'Disease'),
#  ('BiologicalProcess', 'Disease'),
#  ('ComplexMolecularMixture', 'Behavior'),
#  ('GenomicEntity', 'GeneticInheritance'),
#  ('Drug', 'AnatomicalEntity'),
#  ('Food', 'GeneticInheritance'),
#  ('Protein', 'NucleicAcidEntity'),
#  ('ChemicalMixture', 'DiseaseOrPhenotypicFeature'),
#  ('NamedThing', 'BiologicalEntity'),
#  ('SmallMolecule', 'Disease'),
#  ('Protein', 'PhysiologicalProcess'),
#  ('ChemicalEntity', 'PhenotypicFeature'),
#  ('OrganismTaxon', 'Disease'),
#  ('SmallMolecule', 'Activity'),
#  ('Disease', 'PhysiologicalProcess'),
#  ('MolecularActivity', 'PhysiologicalProcess'),
#  ('Polypeptide', 'Disease'),
#  ('Gene', 'Procedure'),
#  ('NamedThing', 'Disease'),
#  ('Behavior', 'PhenotypicFeature'),
#  ('Gene', 'BiologicalEntity'),
#  ('AnatomicalEntity', 'PhenotypicFeature'),
#  ('Gene', 'InformationContentEntity'),
#  ('Protein', 'GeneticInheritance'),
#  ('PhysiologicalProcess', 'ClinicalAttribute'),
#  ('ChemicalEntity', 'Cell'),
#  ('MolecularMixture', 'OrganismAttribute'),
#  ('SmallMolecule', 'Behavior'),
#  ('BiologicalEntity', 'PhysiologicalProcess'),
#  ('ComplexMolecularMixture', 'BiologicalEntity'),
#  ('Activity', 'InformationContentEntity'),
#  ('MolecularActivity', 'GeneticInheritance'),
#  ('Activity', 'Procedure'),
#  ('OrganismAttribute', 'Disease'),
#  ('Event', 'PhenotypicFeature'),
#  ('Disease', 'GeneticInheritance'),
#  ('InformationContentEntity', 'InformationContentEntity'),
#  ('Polypeptide', 'Activity'),
#  ('Phenomenon', 'MolecularActivity'),
#  ('PhenotypicFeature', 'OrganismAttribute'),
#  ('PhysicalEntity', 'PhysiologicalProcess'),
#  ('Procedure', 'OrganismAttribute'),
#  ('Drug', 'ClinicalAttribute'),
#  ('OrganismTaxon', 'Activity'),
#  ('Drug', 'NamedThing'),
#  ('NucleicAcidEntity', 'OrganismAttribute'),
#  ('Device', 'AnatomicalEntity'),
#  ('NucleicAcidEntity', 'NucleicAcidEntity'),
#  ('Device', 'DiseaseOrPhenotypicFeature'),
#  ('ComplexMolecularMixture', 'InformationContentEntity'),
#  ('InformationContentEntity', 'Procedure'),
#  ('Food', 'OrganismAttribute'),
#  ('ComplexMolecularMixture', 'Procedure'),
#  ('MolecularActivity', 'Pathway'),
#  ('Polypeptide', 'Behavior'),
#  ('ChemicalMixture', 'NamedThing'),
#  ('Drug', 'PopulationOfIndividualOrganisms'),
#  ('ClinicalIntervention', 'Disease'),
#  ('NamedThing', 'MaterialSample'),
#  ('ChemicalEntity', 'CellularComponent'),
#  ('OrganismTaxon', 'Behavior'),
#  ('NamedThing', 'Activity'),
#  ('Protein', 'Pathway'),
#  ('CellularComponent', 'Phenomenon'),
#  ('BiologicalEntity', 'GeneticInheritance'),
#  ('PopulationOfIndividualOrganisms', 'PhenotypicFeature'),
#  ('Phenomenon', 'Phenomenon'),
#  ('Gene', 'Cohort'),
#  ('GenomicEntity', 'OrganismAttribute'),
#  ('ChemicalEntity', 'PhysiologicalProcess'),
#  ('Disease', 'PhenotypicFeature'),
#  ('Protein', 'PhenotypicFeature'),
#  ('Device', 'Disease'),
#  ('GeneticInheritance', 'Disease'),
#  ('NucleicAcidEntity', 'MolecularActivity'),
#  ('AnatomicalEntity', 'PhysiologicalProcess'),
#  ('MolecularActivity', 'PhenotypicFeature'),
#  ('MolecularMixture', 'Phenomenon'),
#  ('Drug', 'InformationContentEntity'),
#  ('Gene', 'ClinicalAttribute'),
#  ('GrossAnatomicalStructure', 'PhenotypicFeature'),
#  ('SmallMolecule', 'AnatomicalEntity'),
#  ('PhysiologicalProcess', 'InformationContentEntity'),
#  ('MolecularMixture', 'MolecularActivity'),
#  ('PhysicalEntity', 'PhenotypicFeature'),
#  ('BiologicalEntity', 'PhenotypicFeature'),
#  ('Activity', 'ClinicalAttribute'),
#  ('ChemicalEntity', 'GeneticInheritance'),
#  ('OrganismTaxon', 'AnatomicalEntity'),
#  ('PhenotypicFeature', 'Phenomenon'),
#  ('GenomicEntity', 'Phenomenon'),
#  ('Gene', 'NamedThing'),
#  ('IndividualOrganism', 'PhysiologicalProcess'),
#  ('SmallMolecule', 'DiseaseOrPhenotypicFeature'),
#  ('Polypeptide', 'DiseaseOrPhenotypicFeature'),
#  ('ChemicalMixture', 'InformationContentEntity'),
#  ('Drug', 'BiologicalEntity'),
#  ('Disease', 'Publication'),
#  ('SmallMolecule', 'PathologicalProcess'),
#  ('PathologicalProcess', 'PathologicalProcess'),
#  ('PhysiologicalProcess', 'Procedure'),
#  ('Drug', 'Procedure'),
#  ('Activity', 'PopulationOfIndividualOrganisms'),
#  ('NucleicAcidEntity', 'Phenomenon'),
#  ('PhenotypicFeature', 'MolecularActivity'),
#  ('Behavior', 'PhysiologicalProcess'),
#  ('Food', 'Phenomenon'),
#  ('ChemicalEntity', 'Event'),
#  ('ComplexMolecularMixture', 'NamedThing'),
#  ('SmallMolecule', 'BiologicalProcess'),
#  ('MolecularEntity', 'BiologicalProcess'),
#  ('PathologicalProcess', 'BiologicalProcess'),
#  ('Gene', 'PopulationOfIndividualOrganisms'),
#  ('InformationContentEntity', 'NamedThing'),
#  ('Protein', 'Cell'),
#  ('ComplexMolecularMixture', 'ClinicalAttribute'),
#  ('Polypeptide', 'BiologicalProcess'),
#  ('NamedThing', 'AnatomicalEntity'),
#  ('InformationContentEntity', 'ClinicalAttribute'),
#  ('ChemicalMixture', 'BiologicalEntity'),
#  ('Device', 'Behavior'),
#  ('ChemicalEntity', 'Pathway'),
#  ('Protein', 'CellularComponent'),
#  ('MolecularActivity', 'CellularComponent'),
#  ('GenomicEntity', 'MolecularActivity'),
#  ('MolecularMixture', 'PhenotypicFeature'),
#  ('Drug', 'Disease'),
#  ('PhenotypicFeature', 'PhenotypicFeature'),
#  ('MolecularActivity', 'MolecularActivity'),
#  ('Procedure', 'PhenotypicFeature'),
#  ('NucleicAcidEntity', 'PhenotypicFeature'),
#  ('SmallMolecule', 'ClinicalAttribute'),
#  ('Protein', 'MolecularActivity'),
#  ('Protein', 'Phenomenon'),
#  ('Device', 'Procedure'),
#  ('Food', 'PhenotypicFeature'),
#  ('ChemicalMixture', 'Disease'),
#  ('PhysiologicalProcess', 'Disease'),
#  ('ChemicalEntity', 'OrganismAttribute'),
#  ('Device', 'InformationContentEntity'),
#  ('SmallMolecule', 'NamedThing'),
#  ('PhysiologicalProcess', 'Activity'),
#  ('Disease', 'Phenomenon'),
#  ('GenomicEntity', 'PhenotypicFeature'),
#  ('Phenomenon', 'PhysiologicalProcess'),
#  ('Drug', 'Activity'),
#  ('CellularComponent', 'GeneticInheritance'),
#  ('MolecularActivity', 'Phenomenon'),
#  ('Drug', 'Behavior'),
#  ('ClinicalAttribute', 'PhysiologicalProcess'),
#  ('Disease', 'MolecularActivity'),
#  ('Device', 'BiologicalEntity'),
#  ('Gene', 'AnatomicalEntity'),
#  ('ComplexMolecularMixture', 'DiseaseOrPhenotypicFeature'),
#  ('OrganismTaxon', 'NamedThing'),
#  ('Gene', 'DiseaseOrPhenotypicFeature'),
#  ('PhenotypicFeature', 'Publication'),
#  ('Activity', 'DiseaseOrPhenotypicFeature'),
#  ('InformationContentEntity', 'DiseaseOrPhenotypicFeature'),
#  ('Cell', 'PhysiologicalProcess'),
#  ('Cohort', 'PhenotypicFeature'),
#  ('CellularComponent', 'PhysiologicalProcess'),
#  ('Polypeptide', 'PopulationOfIndividualOrganisms'),
#  ('AnatomicalEntity', 'OrganismAttribute'),
#  ('SmallMolecule', 'PopulationOfIndividualOrganisms'),
#  ('MolecularActivity', 'IndividualOrganism'),
#  ('PhysicalEntity', 'Phenomenon'),
#  ('PhysiologicalProcess', 'Behavior'),
#  ('BiologicalEntity', 'Phenomenon'),
#  ('BiologicalProcess', 'BiologicalProcess'),
#  ('Gene', 'Gene'),
#  ('Phenomenon', 'GeneticInheritance'),
#  ('NamedThing', 'EnvironmentalProcess'),
#  ('OrganismTaxon', 'EnvironmentalProcess'),
#  ('MolecularMixture', 'Cell'),
#  ('CellularComponent', 'Pathway'),
#  ('BiologicalProcess', 'AnatomicalEntity'),
#  ('RNAProduct', 'BiologicalProcess'),
#  ('BiologicalProcess', 'PathologicalProcess'),
#  ('BiologicalEntity', 'MolecularActivity'),
#  ('ChemicalEntity', 'NucleicAcidEntity'),
#  ('Activity', 'AnatomicalEntity'),
#  ('Polypeptide', 'NamedThing'),
#  ('OrganismTaxon', 'ClinicalAttribute'),
#  ('Disease', 'Disease'),
#  ('SmallMolecule', 'PhysiologicalProcess'),
#  ('Protein', 'Disease'),
#  ('Protein', 'Activity'),
#  ('NamedThing', 'PhysiologicalProcess'),
#  ('Device', 'PhenotypicFeature'),
#  ('OrganismTaxon', 'PhysiologicalProcess'),
#  ('Disease', 'Activity'),
#  ('PhysicalEntity', 'Disease'),
#  ('GeneticInheritance', 'PhenotypicFeature'),
#  ('MolecularActivity', 'Disease'),
#  ('PhysiologicalProcess', 'MolecularActivity'),
#  ('OrganismTaxon', 'GeneticInheritance'),
#  ('Polypeptide', 'PhysiologicalProcess'),
#  ('PhenotypicFeature', 'Procedure'),
#  ('BiologicalEntity', 'Disease'),
#  ('Drug', 'MolecularActivity'),
#  ('ChemicalEntity', 'AnatomicalEntity'),
#  ('MolecularMixture', 'InformationContentEntity'),
#  ('GrossAnatomicalStructure', 'Disease'),
#  ('Food', 'InformationContentEntity'),
#  ('AnatomicalEntity', 'Gene'),
#  ('SmallMolecule', 'GeneticInheritance'),
#  ('PhenotypicFeature', 'InformationContentEntity'),
#  ('NucleicAcidEntity', 'Procedure'),
#  ('NucleicAcidEntity', 'InformationContentEntity'),
#  ('Drug', 'Phenomenon'),
#  ('Gene', 'OrganismAttribute'),
#  ('MolecularMixture', 'Procedure'),
#  ('Protein', 'Behavior'),
#  ('ChemicalEntity', 'Gene'),
#  ('Procedure', 'InformationContentEntity'),
#  ('Procedure', 'Procedure'),
#  ('MolecularActivity', 'Protein'),
#  ('MolecularMixture', 'BiologicalEntity'),
#  ('PhysiologicalProcess', 'Phenomenon'),
#  ('Gene', 'NucleicAcidEntity'),
#  ('ChemicalEntity', 'DiseaseOrPhenotypicFeature'),
#  ('GenomicEntity', 'BiologicalEntity'),
#  ('Food', 'BiologicalEntity'),
#  ('NucleicAcidEntity', 'BiologicalEntity'),
#  ('PhenotypicFeature', 'GrossAnatomicalStructure'),
#  ('Disease', 'Behavior'),
#  ('ChemicalEntity', 'PathologicalProcess'),
#  ('ComplexMolecularMixture', 'OrganismAttribute'),
#  ('Polypeptide', 'GeneticInheritance'),
#  ('Phenomenon', 'ClinicalAttribute'),
#  ('PhenotypicFeature', 'SmallMolecule'),
#  ('PhysicalEntity', 'Activity'),
#  ('OrganismAttribute', 'PhysiologicalProcess'),
#  ('ClinicalAttribute', 'ClinicalAttribute'),
#  ('Food', 'Procedure'),
#  ('ChemicalEntity', 'BiologicalProcess'),
#  ('MolecularEntity', 'PhysiologicalProcess'),
#  ('PathologicalProcess', 'PhysiologicalProcess'),
#  ('Pathway', 'BiologicalProcess'),
#  ('GenomicEntity', 'InformationContentEntity'),
#  ('SmallMolecule', 'Event'),
#  ('AnatomicalEntity', 'AnatomicalEntity'),
#  ('AnatomicalEntity', 'BiologicalProcess'),
#  ('Activity', 'OrganismAttribute'),
#  ('Protein', 'Protein'),
#  ('BiologicalEntity', 'Activity'),
#  ('Procedure', 'BiologicalEntity'),
#  ('PhysicalEntity', 'Behavior'),
#  ('Gene', 'PhysiologicalProcess'),
#  ('MolecularMixture', 'Disease'),
#  ('PhenotypicFeature', 'Disease'),
#  ('Drug', 'PhenotypicFeature'),
#  ('Procedure', 'Disease'),
#  ('Food', 'Disease'),
#  ('NucleicAcidEntity', 'Disease'),
#  ('PhysiologicalProcess', 'PhenotypicFeature'),
#  ('PhenotypicFeature', 'Activity'),
#  ('Disease', 'Procedure'),
#  ('Protein', 'InformationContentEntity'),
#  ('Protein', 'Procedure'),
#  ('Disease', 'InformationContentEntity'),
#  ('InformationContentEntity', 'PhysiologicalProcess'),
#  ('MolecularMixture', 'Behavior'),
#  ('ComplexMolecularMixture', 'PhysiologicalProcess'),
#  ('ChemicalEntity', 'NamedThing'),
#  ('SmallMolecule', 'OrganismAttribute'),
#  ('GenomicEntity', 'Disease'),
#  ('Protein', 'BiologicalEntity'),
#  ('ChemicalMixture', 'PhenotypicFeature'),
#  ('SmallMolecule', 'NucleicAcidEntity'),
#  ('MolecularMixture', 'Activity'),
#  ('Gene', 'GeneticInheritance'),
#  ('MolecularActivity', 'InformationContentEntity'),
#  ('AnatomicalEntity', 'NamedThing'),
#  ('ChemicalEntity', 'ClinicalAttribute'),
#  ('OrganismTaxon', 'OrganismAttribute'),
#  ('NucleicAcidEntity', 'Activity'),
#  ('BiologicalEntity', 'InformationContentEntity'),
#  ('Device', 'Phenomenon'),
#  ('PhenotypicFeature', 'Behavior'),
#  ('GeneticInheritance', 'MolecularActivity'),
#  ('BiologicalEntity', 'BiologicalEntity'),
#  ('Polypeptide', 'OrganismAttribute'),
#  ('Disease', 'GrossAnatomicalStructure'),
#  ('BiologicalProcess', 'PhysiologicalProcess'),
#  ('Phenomenon', 'AnatomicalEntity'),
#  ('ChemicalEntity', 'PopulationOfIndividualOrganisms'),
#  ('GenomicEntity', 'Activity'),
#  ('Procedure', 'Behavior'),
#  ('GenomicEntity', 'Behavior'),
#  ('Cohort', 'Disease'),
#  ('NucleicAcidEntity', 'Behavior'),
#  ('PhysicalEntity', 'Procedure'),
#  ('GrossAnatomicalStructure', 'InformationContentEntity'),
#  ('PhysicalEntity', 'InformationContentEntity'),
#  ('Activity', 'PhysiologicalProcess'),
#  ('Procedure', 'Activity'),
#  ('PhysicalEntity', 'BiologicalEntity'),
#  ('Cell', 'BiologicalProcess'),
#  ('Food', 'Behavior'),
#  ('MolecularActivity', 'Procedure'),
#  ('CellularComponent', 'BiologicalProcess'),
#  ('GrossAnatomicalStructure', 'GrossAnatomicalStructure'),
#  ('NamedThing', 'PhysicalEntity'),
#  ('Drug', 'Cell'),
#  ('AnatomicalEntity', 'ClinicalAttribute'),
#  ('GrossAnatomicalStructure', 'BiologicalEntity'),
#  ('Device', 'MolecularActivity'),
#  ('Drug', 'CellularComponent'),
#  ('Phenomenon', 'Disease'),
#  ('Drug', 'PhysiologicalProcess'),
#  ('Gene', 'PhenotypicFeature'),
#  ('ChemicalEntity', 'Procedure'),
#  ('NamedThing', 'Phenomenon'),
#  ('ChemicalEntity', 'BiologicalEntity'),
#  ('ChemicalEntity', 'InformationContentEntity'),
#  ('SmallMolecule', 'MolecularActivity'),
#  ('Activity', 'PhenotypicFeature'),
#  ('PhysiologicalProcess', 'PhysiologicalProcess'),
#  ('CellularComponent', 'Disease'),
#  ('Disease', 'NamedThing'),
#  ('Cell', 'Disease'),
#  ('ComplexMolecularMixture', 'PhenotypicFeature'),
#  ('PhenotypicFeature', 'AnatomicalEntity'),
#  ('Disease', 'ClinicalAttribute'),
#  ('Procedure', 'AnatomicalEntity'),
#  ('Protein', 'ClinicalAttribute'),
#  ('SmallMolecule', 'Phenomenon'),
#  ('AnatomicalEntity', 'BiologicalEntity'),
#  ('MolecularMixture', 'AnatomicalEntity'),
#  ('Protein', 'NamedThing'),
#  ('InformationContentEntity', 'PhenotypicFeature'),
#  ('ClinicalAttribute', 'Disease'),
#  ('AnatomicalEntity', 'InformationContentEntity'),
#  ('Phenomenon', 'Activity'),
#  ('DiseaseOrPhenotypicFeature', 'PhenotypicFeature'),
#  ('Drug', 'GeneticInheritance'),
#  ('MolecularMixture', 'DiseaseOrPhenotypicFeature'),
#  ('GenomicEntity', 'DiseaseOrPhenotypicFeature'),
#  ('Polypeptide', 'Phenomenon'),
#  ('NucleicAcidEntity', 'DiseaseOrPhenotypicFeature'),
#  ('Publication', 'Disease'),
#  ('Polypeptide', 'MolecularActivity'),
#  ('MolecularEntity', 'MolecularActivity'),
#  ('MolecularMixture', 'PathologicalProcess'),
#  ('OrganismTaxon', 'Phenomenon'),
#  ('OrganismTaxon', 'MolecularActivity'),
#  ('ChemicalMixture', 'PhysiologicalProcess'),
#  ('PhysiologicalProcess', 'GeneticInheritance'),
#  ('Device', 'OrganismAttribute'),
#  ('GrossAnatomicalStructure', 'ClinicalAttribute'),
#  ('GeneticInheritance', 'NucleicAcidEntity'),
#  ('Procedure', 'Gene'),
#  ('Drug', 'Event'),
#  ('ClinicalAttribute', 'Activity'),
#  ('MolecularMixture', 'BiologicalProcess'),
#  ('PathologicalProcess', 'MolecularActivity'),
#  ('GrossAnatomicalStructure', 'NamedThing'),
#  ('NucleicAcidEntity', 'AnatomicalEntity'),
#  ('PhenotypicFeature', 'Gene'),
#  ('IndividualOrganism', 'InformationContentEntity'),
#  ('NamedThing', 'MolecularActivity'),
#  ('Phenomenon', 'Behavior'),
#  ('Gene', 'Cell'),
#  ('BiologicalProcess', 'Cell'),
#  ('AnatomicalEntity', 'GrossAnatomicalStructure'),
#  ('NamedThing', 'OrganismTaxon'),
#  ('PhysicalEntity', 'EnvironmentalProcess'),
#  ('Food', 'AnatomicalEntity'),
#  ('AnatomicalEntity', 'Procedure'),
#  ('BiologicalProcess', 'CellularComponent'),
#  ('Behavior', 'InformationContentEntity'),
#  ('NucleicAcidEntity', 'Gene'),
#  ('PhenotypicFeature', 'DiseaseOrPhenotypicFeature'),
#  ('PhysicalEntity', 'ClinicalAttribute'),
#  ('ClinicalAttribute', 'Behavior'),
#  ('PhysicalEntity', 'NamedThing'),
#  ('ComplexMolecularMixture', 'Cell'),
#  ('ChemicalEntity', 'Disease'),
#  ('SmallMolecule', 'PhenotypicFeature'),
#  ('OrganismTaxon', 'PhenotypicFeature'),
#  ('AnatomicalEntity', 'Disease'),
#  ('ChemicalEntity', 'Activity'),
#  ('ChemicalEntity', 'Behavior'),
#  ('Gene', 'MolecularActivity'),
#  ('MolecularMixture', 'ClinicalAttribute'),
#  ('Protein', 'AnatomicalEntity'),
#  ('PhenotypicFeature', 'ClinicalAttribute'),
#  ('Phenomenon', 'Procedure'),
#  ('Device', 'PhysiologicalProcess'),
#  ('InformationContentEntity', 'MolecularActivity'),
#  ('ComplexMolecularMixture', 'Phenomenon'),
#  ('Gene', 'Phenomenon'),
#  ('Protein', 'Gene'),
#  ('GeneticInheritance', 'PhysiologicalProcess'),
#  ('NamedThing', 'PhenotypicFeature'),
#  ('Polypeptide', 'PhenotypicFeature'),
#  ('Event', 'Disease'),
#  ('ComplexMolecularMixture', 'MolecularActivity'),
#  ('Procedure', 'NamedThing'),
#  ('Disease', 'AnatomicalEntity'),
#  ('Drug', 'OrganismAttribute'),
#  ('Behavior', 'Disease'),
#  ('Behavior', 'Behavior'),
#  ('CellularComponent', 'InformationContentEntity'),
#  ('PhenotypicFeature', 'NamedThing'),
#  ('Drug', 'NucleicAcidEntity'),
#  ('Protein', 'DiseaseOrPhenotypicFeature'),
#  ('PhysicalEntity', 'DiseaseOrPhenotypicFeature'),
#  ('Procedure', 'ClinicalAttribute'),
#  ('Disease', 'Gene'),
#  ('Phenomenon', 'InformationContentEntity'),
#  ('MolecularActivity', 'BiologicalProcess'),
#  ('BiologicalProcess', 'MolecularActivity'),
#  ('Food', 'NamedThing'),
#  ('OrganismAttribute', 'PhenotypicFeature'),
#  ('GeneticInheritance', 'GeneticInheritance'),
#  ('SmallMolecule', 'Cell'),
#  ('SmallMolecule', 'CellularComponent'),
#  ('Device', 'GeneticInheritance'),
#  ('PhysiologicalProcess', 'OrganismAttribute'),
#  ('ClinicalAttribute', 'InformationContentEntity'),
#  ('MolecularMixture', 'NamedThing'),
#  ('NucleicAcidEntity', 'ClinicalAttribute'),
#  ('PopulationOfIndividualOrganisms', 'Disease'),
#  ('Cell', 'InformationContentEntity'),
#  ('Device', 'Event'),
#  ('Food', 'ClinicalAttribute'),
#  ('Activity', 'Phenomenon'),
#  ('Disease', 'DiseaseOrPhenotypicFeature'),
#  ('GrossAnatomicalStructure', 'AnatomicalEntity'),
#  ('EnvironmentalProcess', 'Disease'),
#  ('Disease', 'BiologicalProcess'),
#  ('Protein', 'BiologicalProcess'),
#  ('Behavior', 'Activity'),
#  ('BiologicalEntity', 'DiseaseOrPhenotypicFeature'),
#  ('Publication', 'InformationContentEntity'),
#  ('PhysiologicalProcess', 'NucleicAcidEntity'),
#  ('MolecularMixture', 'PopulationOfIndividualOrganisms'),
#  ('NucleicAcidEntity', 'NamedThing'),
#  ('AnatomicalEntity', 'Behavior'),
#  ('OrganismTaxon', 'Cell')]

# %%
def gather_parquet_dataset_size_from_path(parquet_path: str):
    with duckdb.connect() as ddb:
        return int(
            ddb.execute(
                f"""
                SELECT COUNT(*) as count
                FROM read_parquet('{parquet_path}')
                """
            ).fetchone()[0]
        )


for source, target in [
    [
        "data/kg2c_lite_2.8.4.full.dataset.parquet/nodes/*",
        "data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/**",
    ],
    [
        "data/kg2c_lite_2.8.4.full.dataset.parquet/edges/*",
        "data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/**",
    ],
]:
    if gather_parquet_dataset_size_from_path(
        source
    ) != gather_parquet_dataset_size_from_path(target):
        raise ValueError(
            f"Inequal number of rows from parquet source {source} to metanames target {target}."
        )
    else:
        print(f"Equal values from parquet source {source} to metanames target {target}")
# Out:
# Equal values from parquet source data/kg2c_lite_2.8.4.full.dataset.parquet/nodes/* to metanames target data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/**
# Equal values from parquet source data/kg2c_lite_2.8.4.full.dataset.parquet/edges/* to metanames target data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/**
